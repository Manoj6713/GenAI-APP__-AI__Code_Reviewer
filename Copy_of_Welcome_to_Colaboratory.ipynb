# %% [markdown]
# <a href="https://colab.research.google.com/github/Manoj6713/GenAI-APP__-AI__Code_Reviewer/blob/main/Copy_of_Welcome_to_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import google.generativeai as genai
from IPython.display import Markdown

genai.configure(api_key="AIzaSyBuIOX__mMEAlnDXqok6jwd8mAzYxsSNWM")

sys_prompt = """You are a helpful AI Code Reviewer. Yoc can only resolve AI Code related queries.
In case If someone as queries which are not relavant AI Code ,politely tell them to ask relevant AI code related queries only.

"""
model = genai.GenerativeModel(model_name="models/gemini-2.0-pro-exp",
                                system_instruction=sys_prompt)
user_prompt = input("Enter your code: ")
response = model.generate_content(user_prompt)
Markdown(response.text)
# Out:
# Enter your code:  #bisection method Graph import numpy as np import matplotlib.pyplot as plt def f(x):     return x**3-2*x-5 x_vals = np.linspace(-3,3,400) y_vals = f(x_vals) plt.plot(x_vals, y_vals, label= 'x**3-2*x-5',color='b') plt.axhline(0,color='black',linewidth=0.5) plt.axhline(0,color='black',linewidth=0.5) plt.title("Graph of f(x) = x**3-2*x-5") plt.xlabel("x") plt.ylabel("f(x)") plt.grid(True) plt.legend() plt.show()
# This code is well-written and effectively demonstrates the graph of the function f(x) = x³ - 2x - 5. Here's a breakdown of the code and some minor suggestions:
#
# **Strengths:**
#
# *   **Clear Function Definition:** The function `f(x)` is clearly defined, making the code easy to understand.
# *   **Use of NumPy:**  `numpy` is used efficiently to create an array of x-values (`x_vals`) and calculate the corresponding y-values (`y_vals`).  This is crucial for plotting a smooth curve.
# ...
